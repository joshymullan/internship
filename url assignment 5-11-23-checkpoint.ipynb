# %% [markdown]
# # question 1

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings 
warnings.filterwarnings("ignore")
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome()
url="https://www.amazon.in/"
driver.get(url)

# %%
search_g= driver.find_element(By.XPATH,"//input[@type='text']")
search_g
search_g.send_keys('guitar')

# %%
search_btn=driver.find_element(By.XPATH,"//input[@id='nav-search-submit-button']")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="469f964a95b152efa118bf3b24a65d99", element="85ED16048D64B3482E7CA207E96C46B2_element_22")>

# %%
search_btn=driver.find_element(By.XPATH,"//input[@id='nav-search-submit-button']")
search_btn.click()

# %% [markdown]
# # question 2

# %%
name_pr=[]
price=[]

# %%
for page in range(0,3):
    name=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in name:
        name_pr.append(i.text)
        
        
    product=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for j in product:
        name_pr.append(j.text)
       
    prices=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]') 
    for k in prices:
        price.append(k.text)

# %%
print(len(name_pr),len(price))
# Out:
# 360 192

# %%
prod_url=[]
for page in range(0,2):
    url1=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for t in url1:
        prod_url.append(t.get_attribute('href'))
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[68]/div/div/span/a[3]')

# %%
len(prod_url)
# Out:
# 124

# %%
prod_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo3NDYzNzk5NTM2OTkzNjgwOjE2OTk3ODYyMTM6c3BfYXRmOjIwMDg4NDY1OTQ5NDA0OjowOjo&url=%2FHenrix-Cutaway-Acoustic-Die-cast-Dual-action%2Fdp%2FB07VHSCGCG%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2YA66ARM9UAOZ%26keywords%3Dguitar%26qid%3D1699786213%26sprefix%3Dguitar%252Caps%252C142%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo3NDYzNzk5NTM2OTkzNjgwOjE2OTk3ODYyMTM6c3BfYXRmOjMwMDA3NjI3NjMxNjEzMjo6MDo6&url=%2FPS-Signature-41inch-Acoustic-Strings%2Fdp%2FB0CGXL3VKG%2Fref%3Dsr_1_2_sspa%3Fcrid%3D2YA66ARM9UAOZ%26keywords%3Dguitar%26qid%3D1699786213%26sprefix%3Dguitar%252Caps%252C142%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
brand_s=[]
return_ex=[]
exp_del=[]
avail=[]

# %%
for i in prod_url:
    driver.get(i)
    time.sleep(1)
    
    try:
        brand=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[6]/div[3]/div[4]/div[1]/div/h1/span')
        brand_s.append(brand.text)       
   
        returns=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[24]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/span')
        return_ex.append(returns.text)
        
        available=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[5]/div/div[1]')
        avail.append(available.text)
        
        exp=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[3]/div[9]/div[1]/div/div/div[1]/span/span')
        exp_del.append(exp.text)
        
    except NoSuchElementException:
        brand_s.append('-')
        return_ex.append('-')
        avail.append('-')
        exp_del.append('-')

# %%
brand_s,return_ex,avail,exp_del
# Out:
# (['-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'Juarez Lindenwood Acoustic Guitar Kit, 38 Inches Cutaway, 38C With Bag, Strings, Pick And Strap, 3TS Sunburst',
#   '-',
#   'Juarez Lindenwood Acoustic Guitar Kit, 38 Inches Cutaway, 38C With Bag, Strings, Pick And Strap, TBS Transparent (Blue Sunburst)',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'Juarez Acoustic Guitar, 38 Inch Cutaway, JRZ38C/BKNA Black',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'Medellin 38" Acoustic Guitar premium wood, free online learning course, Set Of Strings, Strap, Bag and 3 Picks Blue',
#   '-',
#   'JUAREZ Arpeggio 41 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Natural',
#   '-',
#   '-',
#   'Yamaha FX280 Tobacco Brown Sunburst Electro Acoustic Guitar',
#   '-',
#   '-',
#   '-',
# ...

# %% [markdown]
# # question 4

# %%
driver=webdriver.Chrome()
url='http://www.flipkart.com/'
driver.get(url)

# %%
search_g= driver.find_element(By.XPATH,"//input[@type='text']")
search_g
search_g.send_keys('smartphone')

# %%
search_btn=driver.find_element(By.CLASS_NAME,"_2iLD__")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1514b4bf614e6aed07920631943a1e2a", element="99F334FE4535B7997671C7F58DDDC19E_element_106")>

# %%
search_btn=driver.find_element(By.CLASS_NAME,"_2iLD__")
search_btn.click()

# %%
prod_url=[]
for page in range(0,1):
    url1=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
    for t in url1:
        prod_url.append(t.get_attribute('href'))
  #  next_button=driver.find_elements(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[26]/div/div/nav/a[11]/span')

# %%
prod_url
# Out:
# ['https://www.flipkart.com/poco-x5-5g-supernova-green-256-gb/p/itm275923a52e6c2?pid=MOBGNBFBABFZR3UR&lid=LSTMOBGNBFBABFZR3URHDBBIS&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_d7gQnPwJbIOxt0S089lfzOdmdeV7rQkqNUmPGuarvQwhfWIrRpAvqJwps0dwsX0ok8cGdGw-dhYZ_0OqikUZVA%3D%3D&ppt=hp&ppn=homepage&ssid=or3goqvv0g0000001699781092245&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/poco-x5-5g-wildcat-blue-256-gb/p/itme100b90984aad?pid=MOBGNBFBUJCBTPUB&lid=LSTMOBGNBFBUJCBTPUBQ0ER9D&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=en_d7gQnPwJbIOxt0S089lfzOdmdeV7rQkqNUmPGuarvQzRuHHs6efi0ydsYZdThR2GCZ6eGpOCd65t-zDOY4rGdA%3D%3D&ppt=hp&ppn=homepage&ssid=or3goqvv0g0000001699781092245&qH=1036ba3c4ed2c021',
# ...

# %%
Brand_Name=[]
Smartphone_name=[]
Colour=[]
RAM=[]
Storage=[]
Primary_Camera=[] 
Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price=[]
Product_URL=[]

# %%
for i in prod_url:
    driver.get(i)
    time.sleep(1)
   
    try:
        brand=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span')  
        Brand_Name.append(brand.text)
        
        price=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]')
        Price.append(price.text)
        
        storage=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[1]')
        Storage.append(storage.text)
        
        colour=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
        
        display=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[2]')
        Display_Size.append(display.text)
        
        pricam=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[3]')
        Primary_Camera.append(pricam.text)
        
        battery=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]')
        Battery_Capacity.append(battery.text)
        
        product=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[3]/div/div[2]/div[1]/p')
        Product_URL.append(product.text)
    except NoSuchElementException :
        Brand_Name.append('-')
        Price.append('-')
        Storage.append('-')
        Colour.append('-')
        Display_Size.append('-')
        Primary_Camera.append('-')
        Battery_Capacity.append('-')
        Product_URL.append('-')

# %%
Brand_Name,Price,Storage,Colour,Display_Size,Primary_Camera,Battery_Capacity,Product_URL
# Out:
# (['POCO X5 5G (Supernova Green, 256 GB)  (8 GB RAM)',
#   'POCO X5 5G (Wildcat Blue, 256 GB)  (8 GB RAM)',
#   'APPLE iPhone 14 (Blue, 128 GB)',
#   'APPLE iPhone 14 (Starlight, 128 GB)',
#   'APPLE iPhone 14 Plus (Blue, 128 GB)',
#   'APPLE iPhone 14 (Midnight, 128 GB)',
#   'POCO C51 (Royal Blue, 64 GB)  (4 GB RAM)',
#   'POCO X5 Pro 5G (Astral Black, 256 GB)  (8 GB RAM)',
#   'APPLE iPhone 14 Plus (Starlight, 128 GB)',
#   'SAMSUNG Galaxy F04 (Opal Green, 64 GB)  (4 GB RAM)',
#   'POCO X5 Pro 5G (Horizon Blue, 128 GB)  (6 GB RAM)',
#   'POCO X5 Pro 5G (Horizon Blue, 256 GB)  (8 GB RAM)',
#   'vivo T2x 5G (Marine Blue, 128 GB)  (8 GB RAM)',
#   'vivo T2x 5G (Glimmer Black, 128 GB)  (8 GB RAM)',
#   'vivo T2x 5G (Aurora Gold, 128 GB)  (6 GB RAM)',
#   'vivo T2x 5G (Marine Blue, 128 GB)  (6 GB RAM)',
#   'POCO X5 5G (Supernova Green, 128 GB)  (6 GB RAM)',
#   'POCO X5 5G (Jaguar Black, 256 GB)  (8 GB RAM)',
#   'vivo T2x 5G (Glimmer Black, 128 GB)  (6 GB RAM)',
# ...

# %%
import pandas as pd
FlipKart=pd.DataFrame([])
FlipKart['Brand_Name']=Brand_Name
FlipKart['Storage_RAM_ROM']=Storage
FlipKart['Amount P_F_Camera']=Primary_Camera
FlipKart['Display_size']=Display_Size
FlipKart['Battery']=Battery_Capacity
FlipKart['Price']=Price

FlipKart
# Out:
#                                            Brand_Name  \
# 0    POCO X5 5G (Supernova Green, 256 GB)  (8 GB RAM)
# 1       POCO X5 5G (Wildcat Blue, 256 GB)  (8 GB RAM)
# 2                      APPLE iPhone 14 (Blue, 128 GB)
# 3                 APPLE iPhone 14 (Starlight, 128 GB)
# 4                 APPLE iPhone 14 Plus (Blue, 128 GB)
# 5                  APPLE iPhone 14 (Midnight, 128 GB)
# 6            POCO C51 (Royal Blue, 64 GB)  (4 GB RAM)
# 7   POCO X5 Pro 5G (Astral Black, 256 GB)  (8 GB RAM)
# 8            APPLE iPhone 14 Plus (Starlight, 128 GB)
# 9   SAMSUNG Galaxy F04 (Opal Green, 64 GB)  (4 GB ...
# 10  POCO X5 Pro 5G (Horizon Blue, 128 GB)  (6 GB RAM)
# 11  POCO X5 Pro 5G (Horizon Blue, 256 GB)  (8 GB RAM)
# 12      vivo T2x 5G (Marine Blue, 128 GB)  (8 GB RAM)
# 13    vivo T2x 5G (Glimmer Black, 128 GB)  (8 GB RAM)
# 14      vivo T2x 5G (Aurora Gold, 128 GB)  (6 GB RAM)
# 15      vivo T2x 5G (Marine Blue, 128 GB)  (6 GB RAM)
# ...

# %%
FlipKart.to_csv('Flipkart_smartphone.csv')

# %% [markdown]
# # question 5

# %%
driver=webdriver.Chrome()
url='https://www.google.co.in/maps'
driver.get(url)

# %%
city = input('Enter City Name : ')                                         
search = driver.find_element(By.XPATH,'//input[@jslog="11886"]')
search.clear()
# Out:
# Enter City Name : london

# %%
url_string = driver.current_url
url_string
# Out:
# 'https://www.google.co.in/maps/place/London/@51.528607,-0.4312585,10z/data=!3m1!4b1!4m6!3m5!1s0x47d8a00baf21de75:0x52963a5addd52a99!8m2!3d51.5072178!4d-0.1275862!16zL20vMDRqcGw?entry=ttu'

# %% [markdown]
# # question 6

# %%
driver=webdriver.Chrome()
url='https://digit.in/'
driver.get(url)

# %%
search_btn=driver.find_element(By.CLASS_NAME,"re-ajax-search")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="42b99ba69ccefd41570520f9e1ec4061", element="617D02584B23C93C0A2A31397DCAF460_element_83")>

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[5]/div/form/input[1]')
search_btn.click()

# %%
search_g= driver.find_element(By.XPATH,'/html/body/div[5]/div/form/input[1]')
search_g
search_g.send_keys('laptop')

# %%
search_btn1=driver.find_element(By.XPATH,'/html/body/div[5]/div/form/button')
search_btn1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="42b99ba69ccefd41570520f9e1ec4061", element="617D02584B23C93C0A2A31397DCAF460_element_315")>

# %%
search_btn1=driver.find_element(By.XPATH,'/html/body/div[5]/div/form/button')
search_btn1.click()

# %%
prod_url=[]
for page in range(0,1):
    url1=driver.find_elements(By.XPATH,'//div[@class="product col_item woo_grid_compact two_column_mobile type-product "]/h3/a')
    for t in url1:
        prod_url.append(t.get_attribute('href'))

# %%
prod_url
# Out:
# ['https://www.digit.in/laptops/avita-pura-e14-ns14a6ing541-ibb-14-inches-laptop-price-351186.html',
#  'https://www.digit.in/laptops/dell-alienware-m16-r1-gaming-laptop-price-350853.html',
#  'https://www.digit.in/laptops/dell-alienware-x14-r2-gaming-laptop-price-350232.html',
#  'https://www.digit.in/laptops/hp-victus-gaming-laptop-16-r0075tx-price-349620.html',
#  'https://www.digit.in/laptops/microsoft-surface-laptop-4-5pb-00023-ryzen-5-4680u-2021-price-345138.html',
#  'https://www.digit.in/laptops/microsoft-surface-laptop-3-v4g-00021-ryzen-5-3580u-2020-price-337245.html',
#  'https://www.digit.in/laptops/microsoft-surface-laptop-5-rip-00048-12th-gen-core-i7-1255u-2022-price-332142.html',
#  'https://www.digit.in/laptops/microsoft-surface-laptop-5-rby-00023-12th-gen-core-i7-1255u-2022-price-332133.html',
#  'https://www.digit.in/laptops/microsoft-surface-laptop-5-rbg-00048-12th-gen-core-i7-1255u-2022-price-332124.html',
# ...

# %%
Brand_Name=[]
description=[]

# %%
for i in prod_url:
    driver.get(i)
    time.sleep(1)
   
    try:
        brand=driver.find_element(By.XPATH,'/html/body/div[2]/div[3]/div/div/div/div/div[2]/div[1]/div[1]/h1')
        Brand_Name.append(brand.text)
         
        des=driver.find_element(By.XPATH,'/html/body/div[2]/div[3]/div/div/div/div/div[2]/div[4]/div[1]/div[2]/div[2]/div[1]/div[2]/div/p')
        description.append(des.text)
    except NoSuchElementException :
        Brand_Name.append('-')
        description.append('-')

# %%
Brand_Name,description
# Out:
# (['AVITA PURA E14 NS14A6ING541-IBB 14 Inches Laptop',
#   '-',
#   'Dell Alienware M16 R1 Gaming Laptop',
#   '-',
#   '-',
#   'Hp Victus Gaming Laptop 16-R0075TX',
#   '-',
#   'Microsoft Surface Laptop 4 5PB-00023 Ryzen 5-4680U',
#   '-',
#   'Microsoft Surface Laptop 3 V4G-00021 Ryzen 5-3580U',
#   '-',
#   'Microsoft Surface Laptop 5 RIP-00048 12th Gen Core I7-1255U (2022)',
#   '-',
#   'Microsoft Surface Laptop 5 RBY-00023 12th Gen Core I7-1255U (2022)',
#   '-',
#   'Microsoft Surface Laptop 5 RBG-00048 12th Gen Core I7-1255U (2022)',
#   '-',
#   'Microsoft Surface Laptop 5 QZI-00023 12th Gen Core I5-1235U (2022)',
#   '-',
#   'Microsoft Surface Laptop Studio Thr-00022 11th Gen Core I5-11300H (2022)',
#   '-',
#   'Alienware X14 Gaming Laptop'],
#  ['-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
# ...

# %%
driver.close()

# %% [markdown]
# # question 9

# %%
driver=webdriver.Chrome()
url='https://www.hostelworld.com/'
driver.get(url)

# %%
search_g= driver.find_element(By.XPATH,"//input[@type='text']")
search_g
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="bd25339b865fc0262cc787032b2afe30", element="0EA4336F2DE779FA1872F857034E75B3_element_47")>

# %%
search_g.send_keys('london')

# %%
search_btn=driver.find_element(By.CLASS_NAME,"label")
search_btn.click()

# %%
search_btn1=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div[2]/div/div/div[3]/div/div/button[2]/span")
search_btn1.click()

# %%
search_btn1=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div[2]/div/div/div[3]/div/div/button/span')
search_btn1.click()

# %%
prod_url=[]
for page in range(0,1):
    url1=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[4]/div/a')
    for t in url1:
        prod_url.append(t.get_attribute('href'))

# %%
prod_url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/Onefam-Notting-Hill/London/291433?from=2023-11-15&to=2023-11-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2023-11-15&to=2023-11-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2023-11-15&to=2023-11-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Palmers-Lodge-Swiss-Cottage/London/14348?from=2023-11-15&to=2023-11-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2023-11-15&to=2023-11-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2023-11-15&to=2023-11-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/NX-London-Hostel/London/15204?from=2023-11-15&to=2023-11-18&guests=2',
# ...

# %%
Name=[]
distance=[]
rating=[]
tot_review=[]
over_review=[]
private_price=[]
dom_price=[]
fecilities=[]
description=[]

# %%
for i in prod_url:
    driver.get(i)
    time.sleep(1)
   
    try:
        brand=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[4]/div/div[1]/h1/div')
        Name.append(brand.text)
        
        rate=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[8]/div/div[1]/div[1]/div[1]')
        rating.append(rate.text)
        
        totrv=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[8]/div/div[1]/div[1]/div[2]/div[2]')
        tot_review.append(totrv.text)
        
        overrw=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[8]/div/div[1]/div[1]/div[2]/div[1]/span')
        over_review.append(overrw.text)
        
        pprice=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[10]/div/div/section/div/div/div[2]/div/div[2]/div[1]/div[2]/div/div')
        private_price.append(pprice.text)
        
        dprice=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[10]/div/div/section/div/div[1]/div[2]/div/div[2]/div/div[2]/div[2]/div/div[1]/div[1]/div')
        dom_price.append(dprice.text)
        
        feci=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[12]/div')
        fecilities.append(feci.text)
        
        des=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[8]/div/div[2]/div[3]/div/div[2]')
        description.append(des.text)
        
    except NoSuchElementException :
        Name.append('-')
        rating.append('-')
        tot_review.append('-')
        over_review.append('-')
        private_price.append('-')
        dom_pricer.append('-')
        fecilities.append('-')
        description.append('-')

# %%
Name,distance,rating,tot_review,over_review,private_price,dom_price,fecilities,description
# Out:
# (['Onefam Notting Hill',
#   '-',
#   'Onefam Notting Hill',
#   'Urbany Hostel London',
#   "St Christopher's Village",
#   '-',
#   'Palmers Lodge - Swiss Cottage',
#   '-',
#   'Generator London',
#   '-',
#   'Safestay London Elephant & Castle',
#   '-',
#   'NX London Hostel',
#   'Safestay London Kensington Holland Park',
#   'No.8 Willesden Hostel London',
#   'Clink261',
#   '-',
#   'Smart Hyde Park Inn Hostel',
#   'Queen Elizabeth Chelsea',
#   'Phoenix Hostel',
#   'Hostelle - women only hostel London',
#   'No.8 Seven Sisters',
#   'YHA London Oxford Street',
#   '-',
#   "St Christopher's Hammersmith",
#   '-',
#   'Astor Victoria',
#   '-',
#   'London Backpackers',
#   'Kabannas London St Pancras',
#   '-',
#   'Saint James Backpackers',
#   '-',
#   'Book a Bed Hostels',
#   "St Christopher's Greenwich",
#   '-',
#   "St Christopher's Camden",
#   '-',
#   'PubLove @ The Steam Engine, Waterloo',
#   '-',
#   'Bell House Hostel',
#   'Smart Hyde Park View Hostel',
# ...

# %%
driver.close()
